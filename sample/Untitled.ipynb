# %%
from pykonker.main.api import Client

# %%
import pandas as pd
import geopandas as gpd

# %%
konker = Client()

# %%
username = 'radix@konkerlabs.com'
pwd = '2ZLbCU4DmzxvMYud'
konker.login(username=username, password=pwd)
# Out:
# (<requests_oauthlib.oauth2_session.OAuth2Session at 0x116556a58>,
#  {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....JHIJ2V6sHtCCdVy7xvUcbs8g28fPUk61lGU2Bal5p3k',
#   'token_type': 'bearer',
#   'expires_in': 311551593,
#   'scope': ['trust', 'read', 'write'],
#   'jti': 'f808b68c03624b1191ff72bd8a9ce90f107a0dc8251b4533ac8556ea3118b1949faa17f4d2b9414f918779677c408b4e',
#   'expires_at': 1911661724.1848252})

# %%
apps = pd.json_normalize(konker.get_applications())
# Out:
# {'timestamp': 1600110147, 'code': 200, 'status': 'success', 'result': [{'friendlyName': 'uhhn53st', 'description': None, 'name': 'uhhn53st'}, {'friendlyName': 'globo', 'description': 'devices do projeto da globo de tracking de veiculos eletricos', 'name': 'globo'}]}

# %%
apps
# Out:
#   friendlyName                                        description      name
# 0     uhhn53st                                               None  uhhn53st
# 1        globo  devices do projeto da globo de tracking de vei...     globo

# %%
konker.set_application('globo')
devices = pd.json_normalize(konker.get_all_devices())

# %%
devices
# Out:
#                 id             name description locationName deviceModelName  \
# 0  865083031014764  865083031014764        None      default         default
# 1  865083031013154  865083031013154        None      default         default
# 2  865083031015928  865083031015928        None      default         default
# 3  865083031016884  865083031016884        None      default         default
# 4  865083031015688  865083031015688        None      default         default
# 5  865083031018088  865083031018088        None      default         default
# 6  865083031027774  865083031027774        None      default         default
# 7  865083031017973  865083031017973        None      default         default
# 8  865083031014699  865083031014699        None      default         default
# 9  865083031017205  865083031017205        None      default         default
#
#    active  debug tags                                  guid
# 0    True  False   []  f6bef9f0-9cca-4cdd-9447-ce226ee90842
# 1    True  False   []  90a20c97-7572-48ee-a2fb-ca65298eff77
# 2    True  False   []  f34919f4-1462-4cdf-8fce-6a0db6caaecd
# 3    True  False   []  bcb806e4-3ac6-45cf-99d7-c3b0a79da3a4
# 4    True  False   []  861ed2ef-9d61-435a-b09c-23ef8ee9a19b
# 5    True  False   []  d06066ed-2718-48b8-962b-c79a418b8b00
# 6    True  False   []  cd4a9505-dbd6-4227-a8b4-34e5cd8390e4
# 7    True  False   []  874b344e-123f-4c15-afb4-8a610aa2a06e
# 8    True  False   []  7f625eee-56f5-45f4-ac52-84155e2ec6a4
# 9    True  False   []  7609ce01-6b79-41dc-816a-35e51673ffa0

# %%
# help
data = pd.json_normalize(konker.read_data(guid='f6bef9f0-9cca-4cdd-9447-ce226ee90842'))
# Out:
# Reading channel(f6bef9f0-9cca-4cdd-9447-ce226ee90842.None) from 2020-09-04T00:00:00-03:00 XX....
# Done

# %%
data
# Out:
#                      timestamp         ingestedTimestamp  \
# 0     2020-09-09T16:48:45.451Z  2020-09-09T16:48:45.550Z
# 1         2020-09-09T16:48:17Z  2020-09-10T11:17:47.996Z
# 2         2020-09-09T16:48:14Z  2020-09-09T16:48:14.600Z
# 3         2020-09-09T16:48:12Z  2020-09-09T16:48:15.357Z
# 4         2020-09-09T16:48:12Z  2020-09-09T16:48:17.107Z
# ...                        ...                       ...
# 6368      2020-09-14T15:13:57Z  2020-09-14T15:15:57.014Z
# 6369      2020-09-14T15:13:48Z  2020-09-14T15:15:56.016Z
# 6370      2020-09-14T15:13:45Z  2020-09-14T15:15:43.988Z
# 6371      2020-09-14T15:13:39Z  2020-09-14T15:16:08.030Z
# 6372  2020-09-14T03:50:47.341Z  2020-09-14T03:50:47.679Z
#
#                        incoming.deviceGuid incoming.channel  geolocation.lat  \
# 0     f6bef9f0-9cca-4cdd-9447-ce226ee90842         location       -22.961768
# 1     f6bef9f0-9cca-4cdd-9447-ce226ee90842         location       -22.961742
# 2     f6bef9f0-9cca-4cdd-9447-ce226ee90842         location       -22.961768
# 3     f6bef9f0-9cca-4cdd-9447-ce226ee90842         location       -22.961768
# 4     f6bef9f0-9cca-4cdd-9447-ce226ee90842         location       -22.961768
# ...                                    ...              ...              ...
# 6368  f6bef9f0-9cca-4cdd-9447-ce226ee90842         location       -22.960075
# 6369  f6bef9f0-9cca-4cdd-9447-ce226ee90842         location       -22.959963
# 6370  f6bef9f0-9cca-4cdd-9447-ce226ee90842         location       -22.959882
# 6371  f6bef9f0-9cca-4cdd-9447-ce226ee90842         location       -22.959682
# 6372  f6bef9f0-9cca-4cdd-9447-ce226ee90842         location       -22.958202
#
#       geolocation.lon  payload._lon  payload.gpsSignal  payload.distance  \
# 0          -43.406777    -43.406777                 -1              0.00
# 1          -43.406803    -43.406803                 -1              3.93
# 2          -43.406777    -43.406777                 -1              0.00
# 3          -43.406777    -43.406777                 -1              0.00
# 4          -43.406777    -43.406777                 -1              0.00
# ...               ...           ...                ...               ...
# 6368       -43.402445    -43.402445                 -1            125.35
# 6369       -43.402530    -43.402530                 -1            139.90
# 6370       -43.402615    -43.402615                 -1            138.27
# 6371       -43.402627    -43.402627                 -1            174.07
# 6372       -43.404258    -43.404258                 -1              0.00
#
#      payload.channel  ...  payload.attr.hdop  payload.attr.ignition  \
# 0           location  ...                NaN                    NaN
# 1           location  ...                NaN                    NaN
# 2           location  ...                0.0                  False
# 3           location  ...                NaN                    NaN
# 4           location  ...                NaN                    NaN
# ...              ...  ...                ...                    ...
# 6368        location  ...                1.0                   True
# 6369        location  ...                1.0                   True
# 6370        location  ...                1.0                   True
# 6371        location  ...                1.0                   True
# 6372        location  ...                NaN                    NaN
#
#       payload.attr.odometer  payload.battery payload.attr.power  \
# 0                       NaN              NaN                NaN
# 1                       NaN              NaN                NaN
# 2                     400.0              NaN                NaN
# 3                       NaN              NaN                NaN
# 4                       NaN              NaN                NaN
# ...                     ...              ...                ...
# 6368                34400.0            100.0             12.823
# 6369                34400.0            100.0             12.823
# 6370                34300.0            100.0             12.821
# 6371                34300.0            100.0             12.821
# 6372                    NaN              NaN                NaN
#
#       payload.attr.batteryLevel payload.attr.input  payload.attr.output  \
# 0                           NaN                NaN                  NaN
# 1                           NaN                NaN                  NaN
# 2                           NaN                NaN                  NaN
# 3                           NaN                NaN                  NaN
# 4                           NaN                NaN                  NaN
# ...                         ...                ...                  ...
# 6368                      100.0              129.0                  0.0
# 6369                      100.0              129.0                  0.0
# 6370                      100.0              129.0                  0.0
# 6371                      100.0              129.0                  0.0
# 6372                        NaN                NaN                  NaN
#
#       payload.attr.rpm payload.attr.fuel
# 0                  NaN               NaN
# 1                  NaN               NaN
# 2                  NaN               NaN
# 3                  NaN               NaN
# 4                  NaN               NaN
# ...                ...               ...
# 6368              19.0              20.0
# 6369              19.0              21.0
# 6370              19.0              22.0
# 6371              19.0              22.0
# 6372               NaN               NaN
#
# [6373 rows x 37 columns]
